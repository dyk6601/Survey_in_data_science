# %% [markdown]
# # Simple demo for the first recitation
# ## As we deliberately get errors, please run each cell one-by-one

# %% [markdown]
# This is a simple expression

# %%
1 * 3
# Out:
# 3

# %% [raw]
# Mathematical expressions are similar, with a few exceptions.\
# E.g., we use ** instead of ^ for exponentiation\
# Be careful, ^ is also a valid operator, called XOR, used for bitwise manipulation

# %%
3 ** 4
# Out:
# 81

# %% [markdown]
# Use parantheses for clarity, though the result doesn't change

# %%
2 + 2 * 3
# Out:
# 8

# %%
2 + (2 * 3)
# Out:
# 8

# %% [markdown]
# You can assign values to variables

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %% [markdown]
# Here we are doubling x

# %%
x = x * 2

# %%
print(x)
# Out:
# 10

# %% [markdown]
# This will give a NameError since we didn't define y

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %% [markdown]
# It's common to replace spaces with underscores
# Instead of nycsalestaxrate we use nyc_sales_tax_rate

# %%
nyc_sales_tax_rate = 0.08875

# %%
print(nyc_sales_tax_rate)
# Out:
# 0.08875

# %% [markdown]
# We use comments to make the code readable.\
# There are two ways to comment, # and ''' '''\
# We use # to comment out a single line, and ''' ''' for block comments

# %%
# This is a comment
# x was 10 after doubling
# x = 20
# The above line doesn't do anything since it's commented out

# %%
print(x)
# Out:
# 10

# %%
'''
This is a comment
x was 10 after doubling
x = 20
The above line doesn't do anything since it's commented out
'''
# Out:
# "\nThis is a comment\nx was 10 after doubling\nx = 20\nThe above line doesn't do anything since it's commented out\n"

# %% [markdown]
# Here are a few built-in Python functions

# %%
# Take the absolute value of -1
abs(-1)
# Out:
# 1

# %%
# Round 1.6 to the nearest integer
round(2.1)
# Out:
# 2

# %%
# Find the maximum of numbers
min(4, 6, 10, -1)
# Out:
# -1

# %% [markdown]
# Module: A single Python file containing code.\
# Package: A directory of related modules.\
# Library: A collection of packages and modules offering reusable functionality.\
# \
# We'll use libraries/packages/modules, but we need to import before calling

# %%
math.exp(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 math.exp(4)
#
# NameError: name 'math' is not defined

# %%
# Python's math module
import math

# %%
# e^4
math.exp(4)
# Out:
# 54.598150033144236

# %% [markdown]
# There are multiple libraries that can be used for a certain calculation/task

# %%
# Numpy is a fundamental Python library
# "as" keyword is used for convenience, you can call import numpy too 
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Numpy is a fundamental Python library
#       2 # "as" keyword is used for convenience, you can call import numpy too
# ----> 3 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
numpy.exp(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 numpy.exp(4)
#
# NameError: name 'numpy' is not defined

# %% [markdown]
# You can check out https://numpy.org/doc/stable/user/absolute_beginners.html for a numpy tutorial
